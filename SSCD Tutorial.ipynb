# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dmp\\Dropbox\\dmp\\clients\\marine scotland\\scale_image_analysis\\code\\SSCD'

# %%
# %run sscd.py \
    --img_dir "D:/MSS_Scales_depot/testing_sscd-tool/inputs/" \
    --output_dir "D:/MSS_Scales_depot/testing_sscd-tool/outputs"
# Out:
# Converting images files to jpeg format: 100%|#########################################################################| 26/26 [00:12<00:00,  2.09it/s]

# %%
# %run sscd.py \
    --img_dir "D:/MSS_Scales_depot/testing_sscd-tool/weird inputs/" \
    --output_dir "D:/MSS_Scales_depot/testing_sscd-tool/weird outputs"
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\Dropbox\dmp\clients\marine scotland\scale_image_analysis\code\SSCD\sscd.py in <module>
#     117 if __name__ == "__main__":
#     118
# --> 119     main()
#     120
#     121
#
# ~\Dropbox\dmp\clients\marine scotland\scale_image_analysis\code\SSCD\sscd.py in main()
#     106     #breakpoint()
#     107     # --- Convert image files to jpeg format and saving them in the destination directory
# --> 108     convert_to_jpeg(args["img_dir"], scales_jpegs_dir)
#     109
#     110
#
# ~\Dropbox\dmp\clients\marine scotland\scale_image_analysis\code\SSCD\sscd.py in convert_to_jpeg(input_imgs_dir, output_imgs_dir)
#      55
#      56     if len(img_filepaths) == 0:
# ---> 57         raise Exception('No images of type TIFF or PNG found in input folder')
#      58
#      59     for f in tqdm(img_filepaths, ascii = True, ncols = 150,
#
# ...

# %%
python sscd.py ^
    --img_dir "D:/MSS_Scales_depot/testing_sscd-tool/weird inputs/" ^
    --output_dir "D:/MSS_Scales_depot/testing_sscd-tool/weird outputs"
