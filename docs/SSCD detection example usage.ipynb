# %%
# set the working directory to be the SSCD folder
import os
path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)

# %% [markdown]
# ### Example run
#
# For example purposes, the following run uses a couple of scale images shipped with the repository while directing outputs to a temporary folder.
#
# Copying target images to the `SSCD/data` folder is not reccomended.
#
# Instead, use the `--img_dir` argument to locate where the image files are stored, and set a suitable output location with `--output_dir`.

# %%
# Quick look at the arguments and options (Ctrl+Enter to run notebook cell)
# %run sscd.py --help
# Out:
# usage: sscd.py [-h] --img_dir IMG_DIR --output_dir OUTPUT_DIR
#                [--transect_angles TRANSECT_ANGLES [TRANSECT_ANGLES ...]]
#                [--dets_separate_files DETS_SEPARATE_FILES]
#                [--plot_detections PLOT_DETECTIONS]
#
# *** DESCRIPTION TO DO ***
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --img_dir IMG_DIR     directory path containing scale image files. Expects
#                         .tif images
#   --output_dir OUTPUT_DIR
#                         directory path where outputs will be stored
#   --transect_angles TRANSECT_ANGLES [TRANSECT_ANGLES ...]
#                         choice of angle(s) for radial transects relative to
#                         focus, in degrees
#   --dets_separate_files DETS_SEPARATE_FILES
#                         Require detections in each image to be saved in
#                         separate files
#   --plot_detections PLOT_DETECTIONS
# ...

# %%
# Example run (Ctrl+Enter to run notebook cell)
# %run sscd.py \
    --img_dir "./data/example_scales" \
    --output_dir "C:/SSCD_temp_outputs"\
    --transect_angles 0 45 90 135 180 \
    --dets_separate_files False \
    --plot_detections True
